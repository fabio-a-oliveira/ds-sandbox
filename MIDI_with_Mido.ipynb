# %%
# install mido with: pip install mido
# to use ports: pip install python-rtmidi
import mido

# %%
file = mido.MidiFile('datasets\Bach\cs1-1pre.mid')
file = mido.MidiFile('datasets\Bach\cs1-2all.mid')

# %%
file
# Out:
# <midi file 'datasets\\Bach\\cs1-2all.mid' type 1, 17 tracks, 2036 messages>

# %%
dir(file)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_load',
#  '_save',
#  'add_track',
#  'charset',
#  'clip',
#  'debug',
#  'filename',
#  'length',
#  'play',
#  'print_tracks',
#  'save',
#  'ticks_per_beat',
#  'tracks',
#  'type']

# %%
[msg for msg in file.tracks[1]]
# Out:
# [<meta message midi_port port=0 time=0>,
#  <meta message track_name name='Solo Cello' time=0>,
#  <message program_change channel=0 program=42 time=0>,
#  <message control_change channel=0 control=7 value=100 time=0>,
#  <message control_change channel=0 control=10 value=64 time=0>,
#  <message note_on channel=0 note=59 velocity=100 time=1800>,
#  <message note_on channel=0 note=59 velocity=0 time=120>,
#  <message note_on channel=0 note=59 velocity=100 time=0>,
#  <message note_on channel=0 note=59 velocity=0 time=600>,
#  <message note_on channel=0 note=57 velocity=100 time=0>,
#  <message note_on channel=0 note=57 velocity=0 time=120>,
#  <message note_on channel=0 note=55 velocity=100 time=0>,
#  <message note_on channel=0 note=55 velocity=0 time=120>,
#  <message note_on channel=0 note=54 velocity=100 time=0>,
#  <message note_on channel=0 note=54 velocity=0 time=120>,
#  <message note_on channel=0 note=55 velocity=100 time=0>,
# ...

# %%
file.ticks_per_beat
# Out:
# 480

# %%
dir(file)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_load',
#  '_save',
#  'add_track',
#  'charset',
#  'clip',
#  'debug',
#  'filename',
#  'length',
#  'play',
#  'print_tracks',
#  'save',
#  'ticks_per_beat',
#  'tracks',
#  'type']

# %%
[msg for msg in file]
# Out:
# [<meta message track_name name='untitled' time=0>,
#  <meta message smpte_offset frame_rate=25 hours=32 minutes=0 seconds=3 frames=0 sub_frames=0 time=0>,
#  <meta message time_signature numerator=4 denominator=4 clocks_per_click=24 notated_32nd_notes_per_beat=8 time=0>,
#  <meta message key_signature key='G' time=0>,
#  <meta message set_tempo tempo=240000 time=0>,
#  <meta message midi_port port=0 time=0>,
#  <meta message track_name name='Solo Cello' time=0>,
#  <message program_change channel=0 program=42 time=0>,
#  <message control_change channel=0 control=7 value=100 time=0>,
#  <message control_change channel=0 control=10 value=64 time=0>,
#  <meta message midi_port port=0 time=0>,
#  <meta message track_name name='--------------------------------------' time=0>,
#  <message program_change channel=1 program=42 time=0>,
#  <message control_change channel=1 control=7 value=100 time=0>,
#  <message control_change channel=1 control=10 value=74 time=0>,
# ...

# %%
0.7792209999999999/0.19480524999999999
# Out:
# 4.0

# %%
mido.bpm2tempo(120)
# Out:
# 500000

# %%
mido.tempo2bpm(779221)
# Out:
# 77.0

# %%
tempo = 779221

# %%
mido.tempo2bpm(tempo)
# Out:
# 76.99997818333952

# %%
file.tracks[0][2].dict()
# Out:
# {'type': 'time_signature',
#  'numerator': 4,
#  'denominator': 4,
#  'clocks_per_click': 24,
#  'notated_32nd_notes_per_beat': 8,
#  'time': 0}
